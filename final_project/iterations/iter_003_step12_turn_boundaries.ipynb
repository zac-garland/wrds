# %% [markdown]
# ## Iteration 003 — Step 12: turn boundary validation (1128909)
#
# Runs:
#
# `python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk --checkpoint step12 --check-transcriptid 1128909`

# %%
import subprocess, shlex
cmd = 'python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk --checkpoint step12 --check-transcriptid 1128909'
print(cmd)
print()
subprocess.run(shlex.split(cmd), check=True, cwd='..')
# Out:
# python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk --checkpoint step12 --check-transcriptid 1128909
#
#
# === Step 12 boundary check (transcriptid=1128909) ===
#
# 00 | [Audio Gap] I'll now turn the call over to Arnab Chanda, Vice President of Investor Relations, to begin your conference.
# 01 | Thank you. Good afternoon, everyone, and welcome to NVIDIA's conference call for the fourth quarter and fiscal 2017. Wit
# 02 | Thanks, Arnab. We had a stellar Q4 and fiscal 2017, with records in all of our financial metrics: revenue, gross margin,
# 03 | [Operator Instructions] Your first question comes from the line of C.J. Muse with Evercore.
# 04 | I guess I was hoping to get a little more color on the data center side. Now that we've completed the full fiscal year '
# ...
