# %% [markdown]
# ## Iteration 001 — chunk novelty + chunk salience
#
# Runs:
#
# `python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk`

# %%
import subprocess, shlex
cmd = 'python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk'
print(cmd)
print()
subprocess.run(shlex.split(cmd), check=True, cwd='.')
