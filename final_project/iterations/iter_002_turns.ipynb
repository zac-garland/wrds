# %% [markdown]
# ## Iteration 002 — turns novelty + chunk salience
#
# Runs:
#
# `python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode turns`

# %%
import subprocess, shlex
cmd = 'python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode turns'
print(cmd)
print()
subprocess.run(shlex.split(cmd), check=True, cwd='..')
# Out:
# python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode turns
#
# === Top 10 Most Novel + Salient Segments (mode=turns) ===
#
# Ticker : AAPL  |  Quarter: 2023Q4 | Transcript: 2934643 | Chunk: 12
# Novelty: 0.986  |  Salience: 3.480  |  Cluster: guidance
# Text   : Got it. So the weakness in iPad and Wearables are less of an impact on sort of the margin trajectory in the December quarter, I guess? That's correct, that's correct.
#
# Ticker : MSFT  |  Quarter: 2018Q1 | Transcript: 1377558 | Chunk: 13
# Novelty: 0.981  |  Salience: 0.800  |  Cluster: mgmt_signal
# ...
