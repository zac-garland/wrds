# %% [markdown]
# ## Iteration 004 — Steps 11/13/15: raw turns + exec chunks + alignment (1128909)
#
# Runs:
#
# `python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk --checkpoint step11_13_15 --check-transcriptid 1128909`

# %%
import subprocess, shlex
cmd = 'python audit_top10.py --dev-tickers "AAPL,MSFT,NVDA" --embedding-model "all-MiniLM-L6-v2" --cache-tag "audit_v1" --use-dev-final-subset --mode chunk --checkpoint step11_13_15 --check-transcriptid 1128909'
print(cmd)
print()
subprocess.run(shlex.split(cmd), check=True, cwd='..')
